# %% [markdown]
# <a href="https://colab.research.google.com/github/americofreitasjr/AnaliseSegurancaPublicaRJ/blob/master/Step_2_ISP_Analise_Exploratoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Índice
#
#
#
# 1.   [Step_1_Carregando_a_base_do_ISP](Step_1_Carregando_a_base_do_ISP.ipynb)
# 2.   [Step_2_ISP_Analise_Exploratoria](Step_2_ISP_Analise_Exploratoria.ipynb)
# 3.   [Step_3_ISP_estudo_da_serie_historica](Step_3_ISP_estudo_da_serie_historica.ipynb)
# 4.   [Step_4_Serie_Temporal](Step_4_Serie_Temporal.ipynb)

# %% [markdown]
# #Análise exploratória

# %% [markdown]
# Importando e instalando os pacotes

# %%
requiredPackages = c('tidyverse','gdata','caret','plyr','rlang','digest','DataExplorer')
for(p in requiredPackages){
  if(!require(p,character.only = TRUE)) suppressMessages(suppressWarnings(install.packages(p)))
  suppressMessages(suppressWarnings(library(p,character.only = TRUE)))
}
# Out:
# Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.2.0     ✔ purrr   0.3.2
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   0.8.3     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Loading required package: gdata
# gdata: read.xls support for 'XLS' (Excel 97-2004) files ENABLED.
#
# gdata: Unable to load perl libaries needed by read.xls()
# gdata: to support 'XLSX' (Excel 2007+) files.
#
# gdata: Run the function 'installXLSXsupport()'
# gdata: to automatically download and install the perl
# gdata: libaries needed to support Excel XLS and XLSX formats.
#
# Attaching package: ‘gdata’
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, first, last
#
# The following object is masked from ‘package:purrr’:
#
#     keep
#
# The following object is masked from ‘package:stats’:
#
#     nobs
#
# The following object is masked from ‘package:utils’:
#
#     object.size
#
# The following object is masked from ‘package:base’:
#
#     startsWith
#
# Loading required package: caret
# Loading required package: lattice
#
# Attaching package: ‘caret’
#
# The following object is masked from ‘package:purrr’:
#
#     lift
#
# Loading required package: plyr
# ------------------------------------------------------------------------------
# You have loaded plyr after dplyr - this is likely to cause problems.
# If you need functions from both plyr and dplyr, please load plyr first, then dplyr:
# library(plyr); library(dplyr)
# ------------------------------------------------------------------------------
#
# Attaching package: ‘plyr’
#
# The following objects are masked from ‘package:dplyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
# The following object is masked from ‘package:purrr’:
#
#     compact
#
# Loading required package: rlang
#
# Attaching package: ‘rlang’
#
# The following objects are masked from ‘package:gdata’:
#
#     env, ll
#
# The following objects are masked from ‘package:purrr’:
#
#     %@%, as_function, flatten, flatten_chr, flatten_dbl, flatten_int,
#     flatten_lgl, flatten_raw, invoke, list_along, modify, prepend,
#     splice
#
# Loading required package: digest
# Loading required package: DataExplorer

# %% [markdown]
# Carregando dados já obtidos no "Step_1_Carregando_a_base_do_ISP"

# %%
options(warn=-1)
load(file="df_isp.RData")
introduce(df_isp)
# Out:
#   rows    columns discrete_columns continuous_columns all_missing_columns
# 1 5650461 23      21               2                  0
#   total_missing_values complete_rows total_observations memory_usage
# 1 0                    5650461       129960603          917245296

# %%
summary(df_isp)
# Out:
#           controle            ano            MES
#  96136441-2016:     58   Min.   :2010   março  : 503669
#  14903031-2013:     56   1st Qu.:2012   janeiro: 493114
#  83131641-2015:     56   Median :2014   maio   : 491771
#  27025371-2011:     54   Mean   :2014   agosto : 488192
#  30923051-2012:     51   3rd Qu.:2016   abril  : 482851
#  07411121-2015:     51   Max.   :2018   julho  : 479682
#  (Other)      :5650135                  (Other):2711182
#                               titulo_do               total_rbft
#  Lesão corporal dolosa             : 700874   Furto        :1495237
#  Ameaça                            : 657393   não se aplica:2777018
#  Roubo a transeunte                : 621249   Roubo        :1378206
#  Lesão corporal culposa de trânsito: 353511
#  Furto (outros)                    : 308436
#  Roubo de veículo                  : 288474
#  (Other)                           :2720524
#     conteudo                                                DP
#  ambos  :   2009   Delegacia de Roubos e Furtos de Automóveis: 195938
#  casos  :3721751   035a. Campo Grande                        : 139551
#  vítimas:1926701   059a. Duque de Caxias                     : 137367
#                    034a. Bangu                               : 129095
#                    064a. Vilar dos Teles                     : 105822
#                    074a. Alcantara                           : 102949
#                    (Other)                                   :4839739
#       cisp             data_com            data_fato           hora_com
#  Min.   :  1.0   3/04/2017 :   2979             :   9271   99      :   8858
#  1st Qu.: 27.0   4/04/2017 :   2890   1/01/2014 :   3161   16:00:00:   3949
#  Median : 52.0   10/04/2017:   2798   1/03/2014 :   3118   15:00:00:   3789
#  Mean   : 56.5   19/02/2018:   2786   1/01/2013 :   3111   17:00:00:   3489
#  3rd Qu.: 74.0   24/02/2014:   2767   1/01/2015 :   2809   14:00:00:   3448
#  Max.   :168.0   17/04/2017:   2737   18/02/2012:   2801   12:00:00:   3188
#                  (Other)   :5633504   (Other)   :5626190   (Other) :5623740
#    hora_fato                          bairro_fato
#  99     : 277012   CENTRO                   : 452810
#  10:00  : 206919   sem informação           : 353870
#  08:00  : 169648   Centro                   : 183987
#  00:00  : 167372   < bairro nao cadastrado >:  98766
#  20:00  : 155590   CAMPO GRANDE             :  74788
#  12:00  : 147386   COPACABANA               :  68797
#  (Other):4526534   (Other)                  :4417443
#             municipio_fato         aisp              RISP
#  Rio de Janeiro    :2746486   AISP 20: 381339   RISP 01:1427314
#  São Gonçalo       : 329792   AISP 07: 329792   RISP 02:1319172
#  Duque de Caxias   : 312381   AISP 15: 312381   RISP 03:1160172
#  Nova Iguaçu       : 257043   AISP 09: 262174   RISP 04: 875558
#  Niterói           : 217072   AISP 12: 260364   RISP 05: 296646
#  São João de Meriti: 148924   AISP 03: 253902   RISP 06: 349689
#  (Other)           :1638763   (Other):3850509   RISP 07: 221910
#              sexo              data_nasc                   cor
#  feminino      :1078799             :3862457   não se aplica :3721751
#  ignorado      :   3082   1/01/1980 :    302   branca        : 835316
#  masculino     : 816993   1/01/1990 :    232   parda         : 715627
#  não se aplica :3721751   2/05/1988 :    220   negra         : 258976
#  sem informação:  29836   8/02/1982 :    215   ignorado      :  71491
#                           18/01/1983:    213   sem informação:  43627
#                           (Other)   :1786822   (Other)       :   3673
#           profissao                    relacao
#  não se aplica :3721751   Não se aplica    :3721751
#  Ignorado      : 196358   Nenhuma          : 663765
#  Do lar        : 189693   Ignorado         : 186779
#  Estudante     : 177363   Companheiro(a)   : 184932
#  Outros        : 156917   Ex-companheiro(a): 179443
#  sem informação: 145892   Outra            : 169174
#  (Other)       :1062487   (Other)          : 544617
#                      bairro_vit              municipio_vit
#  não se aplica            :3721751   não se aplica  :3721751
#  sem informação           : 284917   RIO DE JANEIRO : 522388
#  CENTRO                   :  48434   Rio de janeiro : 171335
#  CAMPO GRANDE             :  23274   sem informação : 170491
#  Centro                   :  17360   DUQUE DE CAXIAS:  67107
#  < bairro nao cadastrado >:  16630   NOVA IGUAÇU    :  63555
#  (Other)                  :1538095   (Other)        : 933834

# %%
plot_intro(df_isp)
# Out:
# plot without title

# %%
plot_missing(df_isp)
# Out:
# plot without title

# %%
options(warn=-1)
plot_bar(df_isp)
# Out:
# 13 columns ignored with more than 50 categories.
# controle: 5143986 categories
# titulo_do: 71 categories
# DP: 199 categories
# data_com: 3194 categories
# data_fato: 7006 categories
# hora_com: 86401 categories
# hora_fato: 1442 categories
# bairro_fato: 118610 categories
# municipio_fato: 92 categories
# data_nasc: 33973 categories
# profissao: 791 categories
# bairro_vit: 94254 categories
# municipio_vit: 2248 categories
# plot without title

# %%
plot_histogram(df_isp)
# Out:
# plot without title

# %%
plot_correlation(df_isp)
# Out:
# 15 features with more than 20 categories ignored!
# controle: 5143986 categories
# titulo_do: 71 categories
# DP: 199 categories
# data_com: 3194 categories
# data_fato: 7006 categories
# hora_com: 86401 categories
# hora_fato: 1442 categories
# bairro_fato: 118610 categories
# municipio_fato: 92 categories
# aisp: 41 categories
# data_nasc: 33973 categories
# profissao: 791 categories
# relacao: 43 categories
# bairro_vit: 94254 categories
# municipio_vit: 2248 categories
# plot without title

# %%
qq_data <- df_isp[, c("titulo_do","ano")]
plot_qq(qq_data,by="titulo_do", sampled_rows = 1000L)
# Out:
# Error in df[, c("titulo_do", "ano")]: object of type 'closure' is not subsettable
# Traceback:
