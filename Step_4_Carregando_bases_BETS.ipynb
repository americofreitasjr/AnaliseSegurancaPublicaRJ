# %% [markdown]
# <a href="https://colab.research.google.com/github/americofreitasjr/AnaliseSegurancaPublicaRJ/blob/master/Step_4_Carregando_bases_BETS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Carregando a base do ISP

# %% [markdown]
# Importando e instalando os pacotes

# %%
options(warn=-1)

requiredPackages = c('plyr','grnn', 'ggplot2', 'plotly', 'urca', 'forecast', 'zoo', 'rmarkdown', 'foreign', 'seasonal', 'stringr', 'dygraphs', 'shiny', 'miniUI', 'rstudioapi', 'DT', 'webshot', 'RMySQL', 'digest', 'DBI', 'rjson', 'rvest', 'xml2', 'lubridate', 'htmltools', 'httr', 'dplyr', 'sqldf','BETS','forecast')
for(p in requiredPackages){
  if(!require(p,character.only = TRUE)) suppressMessages(suppressWarnings(install.packages(p)))
  suppressMessages(suppressWarnings(library(p,character.only = TRUE)))
}

# %%
emprego <- BETSget(code = 13395)

# %%
summary(emprego)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  -40658   -3936    4825    3236   12072   31965

# %%
plot(emprego)
# Out:
# plot without title

# %%
fit1 <- rwf(EuStockMarkets[1:200,1],h=100)
fit2 <- meanf(EuStockMarkets[1:200,1],h=100)
accuracy(fit1)
accuracy(fit2)
accuracy(fit1,EuStockMarkets[201:300,1])
accuracy(fit2,EuStockMarkets[201:300,1])
plot(fit1)
lines(EuStockMarkets[1:300,1])
# Out:
#              ME        RMSE    MAE      MPE        MAPE      MASE ACF1
# Training set 0.4393467 15.8461 8.959648 0.02128535 0.5533582 1    -0.007760885
#              ME          RMSE     MAE      MPE        MAPE     MASE
# Training set 6.24991e-14 57.83723 46.98108 -0.1240662 2.865357 1
#              ME        RMSE    MAE       MPE         MAPE      MASE
# Training set 0.4393467 15.8461  8.959648  0.02128535 0.5533582 1.00000
# Test set     0.8900000 78.1811 63.311200 -0.16763307 3.7897316 7.06626
#              ACF1
# Training set -0.007760885
# Test set               NA
#              ME           RMSE      MAE       MPE        MAPE     MASE
# Training set 6.249910e-14  57.83723  46.98108 -0.1240662 2.865357 1.000000
# Test set     8.429485e+01 114.96571 105.65361  4.7004265 6.075968 2.248855
# Plot with title “Forecasts from Random walk”

# %% [markdown]
# Definindo o caminho dos arquivos para download e as credenciais de acesso
